# %% [markdown]
# <a href="https://colab.research.google.com/github/ragasafranz/netflixx/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# %%
df=pd.read_csv ("https://raw.githubusercontent.com/ragasafranz/netflixx/main/diabetes-dataset.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
Data = df [['Pregnancies','Age']].values

# %%
plt.scatter(Data[:, 0], Data[:, 1], s=50, cmap='viridis')
plt.title("Original Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# <ipython-input-70-488c59aac487>:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(Data[:, 0], Data[:, 1], s=50, cmap='viridis')

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
predicted_labels = kmeans.fit_predict(Data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df = df.set_index('Pregnancies','Age')
df.index = pd.to_datetime(df.index)
# Out:
# <ipython-input-72-213775524d83>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.set_index except for the argument 'keys' will be keyword-only.
#   df = df.set_index('Pregnancies','Age')

# %%
def create_features(df):
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.day_of_week
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['dayofyear'] = df.index.dayofyear
    return df

df = create_features(df)

# %%
plt.scatter(Data[:, 0], Data[:, 1], c=predicted_labels, s=50, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title("Initial Clustering Result")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %%
for iteration in range(2):  # Repeat for a few iterations (you can adjust this number)
    # Step 3: Reassign Data Points
    predicted_labels = kmeans.predict(Data)

    # Step 4: Update Centroids
    kmeans.cluster_centers_ = np.array([Data[predicted_labels == i].mean(axis=0) for i in range(kmeans.n_clusters)])

    # Visualization
    plt.scatter(Data[:, 0], Data[:, 1], c=predicted_labels, s=50, cmap='viridis')
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
    plt.title(f"Iteration {iteration + 1}")
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.legend()
    plt.show()
